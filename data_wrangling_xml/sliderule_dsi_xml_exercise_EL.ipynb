# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET
import operator

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse( './data/mondial_database_less.xml' )

# %%
# print names of all countries
for child in document_tree.getroot():
    print child.find('name').text
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
# print names of all countries and their cities
for element in document_tree.iterfind('country'):
    print '* ' + element.find('name').text + ':',
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print capitals_string[:-2]
# Out:
# * Albania: Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece: Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia: Skopje, Kumanovo
# * Serbia: Beograd, Novi Sad, Niš
# * Montenegro: Podgorica
# * Kosovo: Prishtine
# * Andorra: Andorra la Vella

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
document = ET.parse( './data/mondial_database.xml' )

# %%
#1. 10 countries with the lowest infant mortality rates
list = []
for element in document_tree.iterfind('country'):
    if element.find('infant_mortality') is None:
        pass
    else:
        country = element.find('name').text 
        rate = float(element.find('infant_mortality').text)
        list.append([country,rate])
print(sorted(list,key=operator.itemgetter(1),reverse=True)[0:9])
# Out:
# [['Albania', 13.19], ['Macedonia', 7.9], ['Serbia', 6.16], ['Greece', 4.78], ['Andorra', 3.69]]

# %%
#2. 10 cities with the largest population
list = []
for element in document_tree.iterfind('country'):
        country = element.find('name').text 
        lastpop = element.findall('population[last()]')[0]
        lastpop = int(float(lastpop.text))
        list.append([country,lastpop])

# %%
sorted_list=sorted(list,key=operator.itemgetter(1))[0:9]
print(sorted_list)
# Out:
# [['Andorra', 78115], ['Montenegro', 620029], ['Kosovo', 1733872], ['Macedonia', 2059794], ['Albania', 2800138], ['Serbia', 7120666], ['Greece', 10816286]]

# %%
#3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
list = {}
for country in document.iterfind('country'):
    if country.find('./ethnicgroup[1][@percentage]') is None:
        pass
    else:
        lastpop = int(country.find('./population[last()]').text)
        ethnic = country.find('./ethnicgroup[1]')
        ethnicname = ethnic.text
        ethicperc = float(ethnic.get('percentage'))/100
        print (country.find('name').text, ethnicname)
        print (lastpop * ethicperc)
        list[country.find('name').text, ethnicname] = lastpop * ethicperc
# Out:
# Albania Albanian
# 2660131.1
# Greece Greek
# 10059145.98
# Macedonia Macedonian
# 1322387.7480000001
# Serbia Serb
# 5903032.114
# Montenegro Montenegrin
# 266612.47
# Kosovo Albanian
# 1595162.24
# Andorra Spanish
# 33589.45
# Spain Mediterranean Nordic
# 46815916.0
# Austria Austrian
# 7743280.448999999
# Czech Republic Czech
# 9548241.456
# Germany German
# 73401020.925
# Hungary Hungarian
# 9172430.644
# Liechtenstein Italian
# 1831.8000000000002
# Slovakia Slovak
# 4625259.852
# Slovenia Slovene
# 1873527.11
# Switzerland German
# 5290760.15
# Belarus Belorussian
# 7682081.904
# Latvia Latvian
# 1305309.228
# Lithuania Lithuanian
# 2502620.4
# Poland German
# 500939.25700000004
# Ukraine Ukrainian
# 35502969.586
# Russia Russian
# 114646210.938
# Belgium Fleming
# 6437741.319999999
# Luxembourg Luxembourgish
# 331182.243
# Netherlands Dutch
# 13592447.067000002
# Bosnia and Herzegovina Muslim
# 1819978.5599999998
# Croatia Croat
# 3844388.3519999995
# Bulgaria Bulgarian
# 5601820.488
# Romania Romanian
# 17928382.130999997
# Turkey Turkish
# 63935390.4336
# Estonia Estonian
# 889290.5850000001
# Faroe Islands Scandinavian
# 48197.0
# Finland Finn
# 5095033.512
# Norway Norwegian
# 4167301.875
# Sweden Swede
# 7931391.1899999995
# Monaco French
# 17317.149999999998
# Guernsey Norman-French
# 59807.0
# Iceland Celt
# 318452.0
# Ireland Irish
# 4010132.2480000006
# Jersey Norman-French
# 97857.0
# Moldova Moldavian/Romanian
# 2783561.062
# Svalbard Norwegian
# 1037.088
# United Kingdom English
# 53592326.743999995
# Afghanistan Tajik
# 6505775.0
# China Han Chinese
# 1245058800.0
# Iran Arab
# 2254490.07
# Tajikistan Tajik
# 6520718.9
# Turkmenistan Turkmen
# 4285695.75
# Uzbekistan Uzbek
# 22215416.0
# Armenia Armenian
# 2957260.783
# Georgia Georgian
# 3757424.4
# Azerbaijan Azeri
# 8476989.0
# Bahrain Arab
# 123459.6
# Bangladesh Bengali
# 146776916.72
# Myanmar Indian
# 1028388.4
# India Dravidian
# 302713744.25
# Bhutan Bhote
# 366502.0
# Brunei Chinese
# 78674.40000000001
# Malaysia Malay
# 13893173.784
# Laos Lao Loum
# 4429813.760000001
# Thailand Chinese
# 9237432.260000002
# Cambodia Chinese
# 143649.31
# Vietnam Viet/Kinh
# 76078375.3
# Kazakhstan Kazakh
# 10831265.809
# Kyrgyzstan Kyrgyz
# 3749013.4
# Hong Kong Chinese
# 6717997.199999999
# Macao Chinese
# 524877.85
# Mongolia Mongol
# 2614196.0650000004
# Christmas Island Chinese
# 1450.3999999999999
# Cyprus Greek
# 647113.39
# Gaza Strip Jewish
# 10560.222
# Israel Jewish
# 5669161.152
# Egypt European
# 836670.47
# Indonesia Javanese
# 113456006.10000001
# Iraq Kurdish
# 4999576.8
# Jordan Armenian
# 62490.0
# Kuwait Arab
# 1047052.9999999999
# Saudi Arabia Arab
# 24423279.3
# Syria Arab
# 18841998.0
# Lebanon Armenian
# 173643.68
# West Bank Jewish
# 474356.27
# Japan Japanese
# 126534212.00000001
# United Arab Emirates South Asian
# 4220768.5
# Philippines Chinese
# 1385067.78
# Qatar Indian
# 305898.3
# Singapore Indian
# 324908.8
# Sri Lanka Sinhalese
# 14995155.02
# Taiwan Chinese
# 3264215.0800000005
# Anguilla Black
# 11746.337
# Aruba European/Caribbean Amerindian
# 81187.20000000001
# Barbados European
# 11112.84
# Belize Mestizo
# 152416.877
# Guatemala Mestizo
# 7536687.5
# Mexico Mestizo
# 67401922.8
# Bermuda Black
# 34687.98
# British Virgin Islands Black
# 19316.274
# Canada British Isles
# 9844325.120000001
# United States European
# 254958101.97759998
# Cayman Islands Black
# 11138.2
# Costa Rica Mestizo
# 3532108.06
# Nicaragua Mestizo
# 4189021.05
# Panama Mestizo
# 2860882.92
# Cuba European
# 7269928.574999999
# Dominica Carib Indians
# 70739.0
# Dominican Republic Mulatto
# 6895055.13
# Haiti African
# 9401580.0
# El Salvador Mestizo
# 5661378.0
# Honduras Mestizo
# 7241391.0
# Greenland Danish
# 7891.800000000001
# Grenada African
# 103328.0
# Guadeloupe Chinese
# 20231.75
# Jamaica African
# 2058561.029
# Martinique Chinese
# 19614.55
# Colombia Mestizo
# 27643836.459999997
# Puerto Rico White
# 2988082.7780000004
# Saint Kitts and Nevis African
# 52352.0
# Saint Lucia African
# 149532.285
# Saint Pierre and Miquelon Basques Bretons
# 6312.0
# Trinidad and Tobago Chinese
# 13280.19
# Turks and Caicos Islands African
# 28312.2
# American Samoa Caucasian
# 1110.38
# Australia European
# 21284458.52
# Cook Islands Polynesian
# 16637.39
# Fiji Indian
# 395857.14
# French Polynesia French
# 26827.0
# Guam Chamorro
# 59121.818
# Kiribati Micronesian
# 103058.0
# Marshall Islands Micronesian
# 53158.0
# Micronesia Polynesian
# 102843.0
# Nauru Chinese
# 802.0
# New Caledonia Vietnamese
# 3438.1199999999994
# New Zealand European
# 2409483.264
# Niue Polynesian
# 1611.0
# Northern Mariana Islands Asian
# 30336.128999999997
# Pitcairn Bounty
# 66.0
# Solomon Islands Chinese
# 1579.3410000000001
# Tuvalu Polynesian
# 9433.92
# Tokelau Polynesian
# 1313.85
# Vanuatu French
# 9451.960000000001
# Wallis and Futuna Polynesian
# 12197.0
# Samoa Europeans
# 751.28
# Argentina European
# 41389415.0
# Bolivia Quechua
# 3008178.6
# Brazil European
# 108886717.794
# Chile Amerindian
# 490257.87
# Paraguay Mestizo
# 6338999.449999999
# Uruguay European
# 2891956.32
# Peru Amerindian
# 13561143.75
# French Guiana Amerindian
# 28505.879999999997
# Guyana East Indian
# 325329.54
# Suriname Hindustani
# 200406.06
# Ecuador Mestizo
# 9414274.35
# Falkland Islands Christian
# 1969.632
# Algeria European
# 370628.2
# Libya Berber Arab
# 5859393.64
# Mali Mande
# 6992980.5
# Mauritania Maur
# 1061210.4
# Morocco Jewish
# 65803.244
# Niger Fula
# 1456790.0950000002
# Tunisia Jewish
# 109827.54000000001
# Angola European
# 243833.01
# Zaire Mangbetu-Azande
# 27986022.45
# Zambia European
# 143511.58800000002
# Benin African
# 9884045.16
# Burkina Faso Mossi
# 4157471.04
# Nigeria African
# 162651570.84
# Togo African
# 6129243.45
# Botswana Batswana
# 1936316.5999999999
# South Africa Indian
# 1346034.56
# Zimbabwe Asian
# 130612.39
# Cote dIvoire Malinke
# 2493846.41
# Ghana European
# 49317.646
# Rwanda Hutu
# 8412778.4
# Tanzania Bantu
# 42682476.85
# Cameroon African
# 2522793.0
# Central African Republic Baya
# 1478973.1400000001
# Cape Verde European
# 4918.75
# Sudan Arab
# 24956401.4
# Guinea Malinke
# 3188691.6
# Liberia African
# 3760090.5
# Djibouti Italian
# 41701.8
# Eritrea Tigrinya
# 3157637.45
# Ethiopia Oromo
# 29090740.514999997
# Somalia Somali
# 8190747.05
# Kenya Arab
# 409091.94
# Gambia African
# 1863625.5
# Senegal Fulani
# 2296481.5500000003
# Guinea-Bissau European
# 15866.24
# Sierra Leone Asian
# 57519.76
# Uganda Rwanda
# 2091408.78
# Lesotho Sotho
# 2002894.237
# Mozambique European
# 14220.428999999998
# Mauritius Creole
# 334014.57
# Swaziland European
# 35794.439999999995
# Saint Helena African descent
# 2831.5
# Sao Tome and Principe European
# 187356.0
# Seychelles Seychellois
# 90945.0

# %%
sorted_list = sorted(list.items(), key=operator.itemgetter(1), reverse=True)[0:9]
print(sorted_list)
# Out:
# [(('China', 'Han Chinese'), 1245058800.0), (('India', 'Dravidian'), 302713744.25), (('United States', 'European'), 254958101.97759998), (('Nigeria', 'African'), 162651570.84), (('Bangladesh', 'Bengali'), 146776916.72), (('Japan', 'Japanese'), 126534212.00000001), (('Russia', 'Russian'), 114646210.938), (('Indonesia', 'Javanese'), 113456006.10000001), (('Brazil', 'European'), 108886717.794)]
